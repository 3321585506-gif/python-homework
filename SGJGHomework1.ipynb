# %% [markdown]
# **练习1**：定义一个 `Rectangle`（矩形）类
#
# 要求：
# 1. 有 `width` 和 `height` 两个属性
# 2. 有 `area()` 方法计算面积
# 3. 有 `perimeter()` 方法计算周长
# 4. 有 `is_square()` 方法判断是否为正方形
#
# ```python
# class Rectangle:
#     def __init__(self, width, height):
#         # TODO: 初始化属性
#         pass
#
#     def area(self):
#         # TODO: 计算面积
#         pass
#
#     def perimeter(self):
#         # TODO: 计算周长
#         pass
#
#     def is_square(self):
#         # TODO: 判断是否为正方形
#         pass
#
# # 测试
# rect = Rectangle(5, 10)
# print(rect.area())        # 50
# print(rect.perimeter())   # 30
# print(rect.is_square())   # False
# ```
#
# **💡 AI 辅助提示**：
# - 向 AI 提问："如何在 Python 类中定义方法？"
# - 让 AI 解释 `self` 的作用
# - 但要自己理解代码逻辑！

# %%
class Rectangle:
    def __init__(self,width,height):
        self.width=width
        self.height=height
    
    def area(self):
        return(self.width*self.height)

    def perimeter(self):
        return((self.width+self.height)*2)
    def is_square(self):
        a="True" if self.width==self.height else "False"
        return a
rect = Rectangle(5, 10)
print(rect.area())       
print(rect.perimeter())   
print(rect.is_square())
# Out:
# 50
# 30
# False
